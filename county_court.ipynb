# %% [markdown]
# ## INFO 348 Project: Eviction

# %%
import pandas as pd
import geopandas as gpd
import geopy.geocoders import Nominatim
from shapely.geometry import Point
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import seaborn as sns
# Out:
#   Cell In[29], line 3
#     import geopy.geocoders import Nominatim
#                            ^
# SyntaxError: invalid syntax

# %%
# Assuming the dataset is in the same directory as the notebook
file_path = 'county_court-issued_2000_2018.csv'
county_df = pd.read_csv(file_path)

county_df
# Out:
#          state           county  fips_state  fips_county  year  renting_hh  \
# 0      Alabama   Autauga County           1         1001  2000        3074
# 1      Alabama   Autauga County           1         1001  2001        3264
# 2      Alabama   Autauga County           1         1001  2002        3454
# 3      Alabama   Autauga County           1         1001  2003        3644
# 4      Alabama   Autauga County           1         1001  2004        3834
# ...        ...              ...         ...          ...   ...         ...
# 33242  Wyoming  Washakie County          56        56043  2017        1030
# 33243  Wyoming    Weston County          56        56045  2014         736
# 33244  Wyoming    Weston County          56        56045  2015         752
# 33245  Wyoming    Weston County          56        56045  2016         768
# 33246  Wyoming    Weston County          56        56045  2017         784
#
# ...

# %%
geolocator = Nominatim(user_agent="your_app_name")

def geocode_location(row):
    location_str = f"{row['county']}, {row['state']}, USA"
    location = geolocator.geocode(location_str)
    if location:
        return location.latitude, location.longitude
    else:
        return None

# %%
county_df[['latitude', 'longitude']] = county_df.apply(geocode_location, axis=1)# Instantiate the geolocator object
geolocator = Nominatim(user_agent="your_app_name")

def geocode_location(row):
    location_str = f"{row['county']}, {row['state']}, USA"
    location = geolocator.geocode(location_str)
    if location:
        return location.latitude, location.longitude
    else:
        return None

# Display the DataFrame with the new 'latitude' and 'longitude' columns
county_df[['state', 'county']]
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# File ~/Library/Python/3.9/lib/python/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#
# File ~/Library/Python/3.9/lib/python/site-packages/urllib3/connection.py:461, in HTTPConnection.getresponse(self)
#     460 # Get the response from http.client.HTTPConnection
# --> 461 httplib_response = super().getresponse()
#     463 try:
#
# File /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/http/client.py:1349, in HTTPConnection.getresponse(self)
#    1348 try:
# -> 1349     response.begin()
# ...

# %%
# Perform data clustering on relevant columns (e.g., vaccination_rate, eviction_rate)
# Standardize the data
scaler = StandardScaler()
scaled_data = scaler.fit_transform(county_df[['vaccination_rate', 'eviction_rate']])

# Use KMeans for clustering
kmeans = KMeans(n_clusters=3, random_state=42)
county_df['cluster'] = kmeans.fit_predict(scaled_data)

# Visualize the clusters
sns.scatterplot(x='vaccination_rate', y='eviction_rate', hue='cluster', data=county_df)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/daniellamichel/Desktop/INFO 348/info348 project/county_court.ipynb Cell 6 line 3
#       <a href='vscode-notebook-cell:/Users/daniellamichel/Desktop/INFO%20348/info348%20project/county_court.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> # Perform data clustering on relevant columns (e.g., vaccination_rate, eviction_rate)
#       <a href='vscode-notebook-cell:/Users/daniellamichel/Desktop/INFO%20348/info348%20project/county_court.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a> # Standardize the data
# ----> <a href='vscode-notebook-cell:/Users/daniellamichel/Desktop/INFO%20348/info348%20project/county_court.ipynb#W5sZmlsZQ%3D%3D?line=2'>3</a> scaler = StandardScaler()
# ...

# %%
# Explore statistical associations between variables
# You can use correlation coefficients, regression analysis, etc.

# Correlation matrix
correlation_matrix = county_df.corr()

# Visualize the correlation matrix
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/daniellamichel/Desktop/INFO 348/info348 project/county_court.ipynb Cell 7 line 5
#       <a href='vscode-notebook-cell:/Users/daniellamichel/Desktop/INFO%20348/info348%20project/county_court.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> # Explore statistical associations between variables
#       <a href='vscode-notebook-cell:/Users/daniellamichel/Desktop/INFO%20348/info348%20project/county_court.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a> # You can use correlation coefficients, regression analysis, etc.
#       <a href='vscode-notebook-cell:/Users/daniellamichel/Desktop/INFO%20348/info348%20project/county_court.ipynb#W6sZmlsZQ%3D%3D?line=2'>3</a>
#       <a href='vscode-notebook-cell:/Users/daniellamichel/Desktop/INFO%20348/info348%20project/county_court.ipynb#W6sZmlsZQ%3D%3D?line=3'>4</a> # Correlation matrix
# ...

# %%
# Select relevant columns for clustering
cluster_columns = ['renting_hh', 'filings_observed', 'ind_filings_court_issued_lt', 'hh_threat_observed']

# %%
# Standardize the data
scaler = StandardScaler()
scaled_data = scaler.fit_transform(county_df[cluster_columns])

# Use KMeans for clustering
kmeans = KMeans(n_clusters=3, random_state=42)
county_df['cluster'] = kmeans.fit_predict(scaled_data

# %%
correlation_matrix = county_df[cluster_columns].corr()

# Visualize the correlation matrix
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.show()
